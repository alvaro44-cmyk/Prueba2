# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaro44-cmyk/Prueba2/blob/main/Chatbot/module%200/chatbotgpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CHATBOT.ARQUITECTURA.TRANSFORMERS.LIBRERIA.
# HUGGINGFACE

# %%
#importar las bibilotecas necesarias
from transformers import AutoTokenizer, BlenderbotForConditionalGeneration, pipeline

# %%
traductor_ingles_espanol = pipeline('translation', model='Helsinki-NLP/opus-mt-en-es')
traductor_espanol_ingles = pipeline('translation', model='Helsinki-NLP/opus-mt-en-es')
# Out:
# config.json:   0%|          | 0.00/1.47k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
mname = 'facebook/blenderbot-400M-distill'
model = BlenderbotForConditionalGeneration.from_pretrained(mname)
tokenizer = AutoTokenizer.from_pretrained(mname)
# Out:
# config.json:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/730M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/127k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/62.9k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/16.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/310k [00:00<?, ?B/s]

# %%
mensajes_despedida = [
    'goodbye', 'see you later', 'farewell', 'until next time', 'take care',
    'adios', 'hasta luego'
]

# %%
def generar_respuesta(entrada_usuario):
  entrada_ingles = traductor_espanol_ingles(entrada_usuario)[0]['translation_text']
  inputs = tokenizer([entrada_ingles], return_tensors='pt')
  replay_ids = model.generate(**inputs)
  respuesta_espanol = traductor_ingles_espanol(tokenizer.batch_decode(replay_ids, skip_special_tokens=True))[0]['translation_text']
  return respuesta_espanol

# %%
print('hola soy un bot voy a hacerte la vida imposible pero tu pregunta ser inferior')
# Out:
# hola soy un bot voy a hacerte la vida imposible pero tu pregunta ser inferior

# %%
while True:
  entrada_usuario = input('usuario: ')

  if entrada_usuario.lower() in mensajes_despedida:
    print('Bot: Adios')
    break


  respuesta = generar_respuesta(entrada_usuario)
  print(f'Bot: {respuesta}')
# Out:
# usuario: hola
# Bot: Las vacaciones son mi época favorita del año. ¿Te gustan las vacaciones?
# usuario: si
# Bot: Hola, ¿cómo estás? Acabo de volver de un paseo con mi perro. ¿Tienes mascotas?
# usuario: cual es tu canción favorita
# Bot: ¿Alguna vez ha probado espresso culinario? Es un tipo de bebida alcohólica hecha de leche fermentada.
# usuario: adios
# Bot: Adios

# %% [markdown]
# NUESTRO CHATBOT

# %%
# !pip install transformers
# !pip install torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
#Importa las librerias necesarias:
from transformers import pipeline
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# %%
#Carga el modelo pre-entrenado GPT-2 en español y el tokenizador correspondiente:
model = GPT2LMHeadModel.from_pretrained("datificate/gpt2-small-spanish")
tokenizer = GPT2Tokenizer.from_pretrained("datificate/gpt2-small-spanish")

# %%
#Define una función que genere respuestas del chatbot:

def chatbot_response(text):
    input_ids = tokenizer.encode(text, return_tensors='pt')
    output = model.generate(input_ids, max_length=100, num_return_sequences=1, no_repeat_ngram_size=2, top_k=50, top_p=0.95, temperature=0.7)
    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
#Inicia una conversación con el chatbot
while True:
    user_input = input("Usuario: ")
    if user_input == 'salir':
        break
    response = chatbot_response(user_input)
    print("Chatbot: ", response)
# Out:
# Usuario: recomiendame una pelicula
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot:  recomiendame una pelicula
# (en inglés: "Dynamic life") es una especie de ave paseriforme de la familia Thamnophilidae. Es nativa de América del Sur, desde el este de México hasta el sur de Guatemala.
#
# Se distribuye por el centro y sur del estado de Chiapas, en el sureste de Oaxaca, y en Guatemala, Belice, Honduras, Nicaragua, Panamá, Costa Rica, El Salvador, Guatemala y Panamá.
#
# Usuario: salir

# %%
# !pip install numpy
# !pip install tensorflow
# !pip install nltk

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=128))
model.add(LSTM(128))
model.add(Dense(10000, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df
# Out:
#       Id  Category               Artists  \
# 0      0         0                Avatar
# 1      1         1           Céline Dion
# 2      2         1                 Adele
# 3      3         1                  Kiss
# 4      4         0            Kanye West
# ..   ...       ...                   ...
# 660  660         0             Radiohead
# 661  661         0                   NaN
# 662  662         0     Kygo|Parson James
# 663  663         0              Gorillaz
# 664  664         1  Gorillaz|ScHoolboy Q
#
#                                                  Track     Version  Duration  \
# 0                                  Hail the Apocalypse         NaN    253660
# 1                                  My Heart Will Go On  Soundtrack    284150
# 2                                              Skyfall  Soundtrack    286480
# 3                            I Was Made for Lovin' You  Soundtrack    268440
# 4                                             Stronger         NaN    311420
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
inputs = tf.keras.layers.Input(shape=(input_shape,))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-e2b572393322> in <cell line: 1>()
# ----> 1 inputs = tf.keras.layers.Input(shape=(input_shape,))
#
# NameError: name 'input_shape' is not defined

# %%
x_train = df[['Category']]
y_train = df['Id']


model = keras.Sequential([
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10)
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

x_test = df[['BPM']]
y_test = df['Duration']
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)

# Realizar predicciones
predictions = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-110-cf0ad7af3b56> in <cell line: 15>()
#      13 x_test = df[['BPM']]
#      14 y_test = df['Duration']
# ---> 15 test_loss, test_acc = model.evaluate(x_test, y_test)
#      16 print('Test accuracy:', test_acc)
#      17
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ...

# %%
def generate_response(input_text):
  # Preprocesar el texto de entrada
  tokenized_input = word_tokenize(input_text)
  # Generar respuesta utilizando el modelo entrenado
  predicted_output = model.predict(tokenized_input)
  return predicted_output

# %%
while True:
  user_input = input("User: ")
  response = generate_response(user_input)
  print(f"Bot: {response}")
# Out:
# User: dime cantantes
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-a1480496f8a2> in <cell line: 1>()
#       1 while True:
#       2   user_input = input("User: ")
# ----> 3   response = generate_response(user_input)
#       4   print(f"Bot: {response}")
#
# <ipython-input-73-e80e95a46f7c> in generate_response(input_text)
#       3   tokenized_input = word_tokenize(input_text)
#       4   # Generar respuesta utilizando el modelo entrenado
# ----> 5   predicted_output = model.predict(tokenized_input)
#       6   return predicted_output
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
# ...

# %%
# !pip install nltk
# !pip install newspaper3k
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 6.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13538 sha256=8a123563ca4fbf75c480ef7a944ea4ee93a7f6ecf9258dd5662357842d7cb43c
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3340 sha256=d58a2175c016c2e0d1b7cf1bab46e205587e6bac6ab38d24a8991aeed65dc33a
# ...

# %%
import nltk
from newspaper import Article
from nltk.chat.util import Chat, reflections

# %%
responses= {
  "saludo": "¡Hola! ¿En qué puedo ayudarte?",
  "despedida": "¡Hasta luego!",
  "nombre": "Mi nombre es Chatbot",
  "desconocido": "Lo siento, no entiendo esa pregunta."
}

# %%
import io
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2ad36968-316c-4bf8-b50f-745ba19282ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ad36968-316c-4bf8-b50f-745ba19282ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb4731cf-63da-4183-9aba-a304e741fefa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb4731cf-63da-4183-9aba-a304e741fefa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pairs = [
    ("Hola", responses["saludo"]),
    ("Adiós", responses["despedida"]),
    ("¿Cómo te llamas?", responses["nombre"])
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-414ebc8e9aab> in <cell line: 2>()
#       1 pairs = [
# ----> 2     ("Hola", responses["saludo"]),
#       3     ("Adiós", responses["despedida"]),
#       4     ("¿Cómo te llamas?", responses["nombre"])
#       5 ]
#
# NameError: name 'responses' is not defined

# %%
def chatbot():
    print("Hola, soy un chatbot. Pregúntame lo que quieras.")
    chat = Chat(pairs, reflections)
    while True:
        user_input = input("Tú: ")
        response = chat.respond(user_input)
        print("Chatbot:", response)

# %%
# !pip install nltk

# %%
import nltk
from nltk.chat.util import Chat, reflections

# %%
pares = [
    [
        r"mi nombre es (.*)",
        ["Hola %1, ¿cómo puedo ayudarte hoy?",]
    ],
    [
        r"cual es tu nombre?",
        ["Mi nombre es Chatbot y estoy aquí para ayudarte",]
    ],
    [
        r"como estas ?",
        ["Estoy bien, gracias. ¿Y tú?",]
    ],
    [
        r"disculpa (.*)",
        ["No te preocupes",]
    ],
    [
        r"(.*) edad (.*)",
        ["No tengo una edad específica",]
    ],
    [
        r"(.*) creado ?",
        ["Fui creado por un programador usando Python y la biblioteca nltk",]
    ],
]

def chatbot():
    print("Hola, soy un chatbot. Puedes preguntarme lo que quieras.")

    chat = Chat(pares, reflections)

    while True:
        mensaje = input("Tú: ")
        if mensaje == "salir":
            print("Hasta luego.")
            break
        respuesta = chat.respond(mensaje)
        print("Chatbot: ", respuesta)

chatbot()
# Out:
# Hola, soy un chatbot. Puedes preguntarme lo que quieras.
# Tú: que edad tienes
# Chatbot:  No tengo una edad específica
# Tú: hola
# Chatbot:  None
# Tú: como estas?
# Chatbot:  Estoy bien, gracias. ¿Y tú?
# Tú: salir
# Hasta luego.

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import pipeline
import torch
import pandas as pd
model = GPT2LMHeadModel.from_pretrained('gpt2')
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
model = GPT2LMHeadModel.from_pretrained("datificate/gpt2-small-spanish")
tokenizer = GPT2Tokenizer.from_pretrained("datificate/gpt2-small-spanish")

# %%
def generate_response(input_text):
    input_ids = tokenizer.encode(input_text, return_tensors='pt')
    output = model.generate(input_ids, max_length=100, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response

# %%
while True:
    user_input = input('Usuario: ')
    if user_input == 'bye':
        print('Chatbot: Adiós! Hasta luego.')
        break

    response = generate_response(user_input)
    print('Chatbot:', response)
# Out:
# Usuario: quien es spiderman?
# Chatbot: quien es spiderman?
#
# En el año 2000, el programa de televisión "The X Factor" se convirtió en un éxito en Estados Unidos, con un total de 3.0 millones de espectadores. En el año 2002, el programa de televisión "The X Factor" se convirtió en un éxito en Estados Unidos, con un total de 3.0 millones de espectadores. En el año 2004, el programa de televisión "The X Factor" se convirtió en un éxito en Estados Unidos,
# Usuario: bye
# Chatbot: Adiós! Hasta luego.
